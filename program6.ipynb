# %%
def water(jug1,jug2,res):
    m=min(jug1,jug2)
    n=max(jug1,jug2)
    print("Maximum capacity of jug1 is %d " %jug1)
    print("Maximum capacity of jug2 is %d " %jug2)
    print("\n")
    m1=0
    m2=0
    while(1):
        if(m1== res):
            print("Finally jug2 contains %d litres of water"%m1)
            print("\n")
            break
        if(m1==0):
            m1=m
            print("The jug2 is filled with %d litres of water" %m1)
            print("\n")
        if(m2==0):
            m2=m1
            m1=m2-m1
            print("%d litres of water from jug2 is poured into jug1 " %m2)
            print("jug2 contains %d litres of water after pouring water to jug1" %m1)
            print("\n")
        elif(m2>0 and m2<n):
            r=n-m2
            m2=m2+r
            m1=m1-r
            print("%d litres of water from jug2 is poured into jug1 " %r)
            print("jug2 contains %d litres of water after pouring water to jug1" %m1)
            print("\n")
        elif(m2==n):
            m2=0
water(4,3,2)
# Out:
# Maximum capacity of jug1 is 4
# Maximum capacity of jug2 is 3
#
#
# The jug2 is filled with 3 litres of water
#
#
# 3 litres of water from jug2 is poured into jug1
# jug2 contains 0 litres of water after pouring water to jug1
#
#
# The jug2 is filled with 3 litres of water
#
#
# 1 litres of water from jug2 is poured into jug1
# jug2 contains 2 litres of water after pouring water to jug1
#
#
# Finally jug2 contains 2 litres of water
