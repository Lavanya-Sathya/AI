# %%
flag=True
count=1
while flag:
    perc=input("enter the percept(clean/dirty) : ")
    loc=input("enter the location(A/B) : ")
    if loc=="A":
        if perc=="dirty":
            print("action: suck...turn right")
            
        elif perc=="clean":
            print("action: turn right")
        else:
            print("Enter either clean or dirty")
            
    elif loc=="B":
        if perc=="dirty":
            print("action: suck.....turn left")
            
        elif perc=="clean":
            print("action: turn left")
        else:
            print("Enter either clean or dirty")
    else:
        print("Enter Either A or B")
    
    print("Do you want to continue?")
    Cont=input("Enter Y or N : ")
    if Cont == 'Y':
         flag= True
    else : 
         flag = False
# Out:
# enter the percept(clean/dirty) : clean
# enter the location(A/B) : A
# action: turn right
# Do you want to continue?
# Enter Y or N : y
